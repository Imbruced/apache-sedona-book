# %%
# %idle_timeout 2880
# %glue_version 4.0
# %worker_type G.1X
# %number_of_workers 5
# %extra_jars https://repo1.maven.org/maven2/org/datasyslab/geotools-wrapper/1.7.2-28.5/geotools-wrapper-1.7.2-28.5.jar,https://repo1.maven.org/maven2/org/apache/sedona/sedona-spark-shaded-3.5_2.12/1.7.2/sedona-spark-shaded-3.5_2.12-1.7.2.jar
# %additional_python_modules apache-sedona==1.7.2

import sys
from awsglue.transforms import *
from awsglue.utils import getResolvedOptions
from pyspark.context import SparkContext
from awsglue.context import GlueContext
from awsglue.job import Job

sc = SparkContext.getOrCreate()
glueContext = GlueContext(sc)
spark = glueContext.spark_session
job = Job(glueContext)

from sedona.spark import *

sedona = SedonaContext.create(spark)

sedona.sql("SELECT ST_POINT(1., 2.) as geom").show()

# %%
# %idle_timeout 2880
# %glue_version 5.0
# %worker_type G.1X
# %number_of_workers 5
# %extra_jars s3://apache-sedona-bucket-123456789/sedona-spark-shaded-3.5_2.12-1.8.0.jar,s3://apache-sedona-bucket-123456789/geotools-wrapper-1.8.0-33.1.jar
# %additional_python_modules apache-sedona==1.8.0


import sys
from awsglue.transforms import *
from awsglue.utils import getResolvedOptions
from pyspark.context import SparkContext
from awsglue.context import GlueContext
from awsglue.job import Job

sc = SparkContext.getOrCreate()
glueContext = GlueContext(sc)
spark = glueContext.spark_session
job = Job(glueContext)

from sedona.spark import *

sedona = SedonaContext.create(spark)

sedona.sql("SELECT ST_POINT(1., 2.) as geom").show()
