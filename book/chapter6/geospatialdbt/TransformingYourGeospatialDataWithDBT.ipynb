# %% [markdown]
# ## Running Apache Sedona with DBT

# %% [markdown]
# # initialize dbt project

# %%
# !dbt deps
# Out:
# 14:43:32  Running with dbt=1.9.4
# 14:43:33  [WARNING]: Deprecated functionality
# The `calogica/dbt_expectations` package is deprecated in favor of
# `metaplane/dbt_expectations`. Please update your `packages.yml` configuration to
# use `metaplane/dbt_expectations` instead.
# 14:43:33  Installing calogica/dbt_expectations
# 14:43:33  Installed from version 0.10.4
# 14:43:33  Up to date!
# 14:43:33  Installing calogica/dbt_date
# 14:43:34  Installed from version 0.10.1
# 14:43:34  Up to date!

# %% [markdown]
# # insert static data

# %%
# !dbt seed
# Out:
# 14:43:35  Running with dbt=1.9.4
# 14:43:35  Registered adapter: spark=1.9.2
# 14:43:36  Unable to do partial parsing because profile has changed
# 14:43:36  [WARNING]: Test 'test.geospatialdbt.test_anomaly' (tests/test_anomaly.sql) depends on a node named 'neighbor_stations' in package '' which was not found
# 14:43:36  [WARNING]: Test 'test.geospatialdbt.test_anomaly' (tests/test_anomaly.sql) depends on a node named 'neighbor_stations' in package '' which was not found
# 14:43:36  [WARNING]: Test 'test.geospatialdbt.test_coverage' (tests/test_coverage.sql) depends on a node named 'neighbor_stations' in package '' which was not found
# 14:43:37  Found 5 models, 11 data tests, 1 seed, 3 sources, 742 macros
# 14:43:37
# 14:43:37  Concurrency: 1 threads (target='local')
# 14:43:37
# 14:43:37  1 of 1 START seed file analytics.stations_raw .................................. [RUN]
# ...

# %% [markdown]
# # run models

# %%
# !dbt run
# Out:
# 14:47:47  Running with dbt=1.9.4
# 14:47:47  Registered adapter: spark=1.9.2
# 14:47:47  Found 5 models, 11 data tests, 1 seed, 3 sources, 742 macros
# 14:47:47
# 14:47:47  Concurrency: 1 threads (target='local')
# 14:47:47
# 14:47:47  1 of 5 START sql table model analytics.germany_neighbors ....................... [RUN]
# 14:47:52  1 of 5 OK created sql table model analytics.germany_neighbors .................. [OK in 4.90s]
# 14:47:52  2 of 5 START sql table model analytics.observations ............................ [RUN]
# 14:48:02  2 of 5 OK created sql table model analytics.observations ....................... [OK in 10.23s]
# 14:48:02  3 of 5 START sql table model analytics.stations ................................ [RUN]
# 14:48:03  3 of 5 OK created sql table model analytics.stations ........................... [OK in 0.51s]
# 14:48:03  4 of 5 START sql table model analytics.grid .................................... [RUN]
# ...

# %% [markdown]
# # test models

# %%
# !dbt test
# Out:
# 15:01:57  Running with dbt=1.9.4
# 15:01:57  Registered adapter: spark=1.9.2
# 15:01:58  Found 5 models, 11 data tests, 1 seed, 3 sources, 742 macros
# 15:01:58
# 15:01:58  Concurrency: 1 threads (target='local')
# 15:01:58
# 15:01:58  1 of 11 START test dbt_expectations_expect_column_values_to_be_in_set_germany_neighbors_country__FR__BE__CH__LU__NL__DE__AT__CZ__DK__PL__DE  [RUN]
# 15:01:58  1 of 11 PASS dbt_expectations_expect_column_values_to_be_in_set_germany_neighbors_country__FR__BE__CH__LU__NL__DE__AT__CZ__DK__PL__DE  [PASS in 0.40s]
# 15:01:58  2 of 11 START test dbt_expectations_expect_column_values_to_be_in_set_stations_country__Poland__Germany__France__Belgium__Switzerland__Luxembourg__Netherlands__Austria__Czechia__Denmark  [RUN]
# 15:01:59  2 of 11 PASS dbt_expectations_expect_column_values_to_be_in_set_stations_country__Poland__Germany__France__Belgium__Switzerland__Luxembourg__Netherlands__Austria__Czechia__Denmark  [PASS in 0.30s]
# ...
